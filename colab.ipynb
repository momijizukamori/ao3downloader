# %%
from ao3downloader.actions import ao3download

# %%
ao3download.action()
# Out:
# use saved download type list? (y/n)
# y
# do you want to create series subfolders? (y/n)
# n
# do you want to start downloading from the page you stopped on last time? (y/n)
# n
# please enter link to ao3
# https://archiveofourown.org/users/momijizukamori/bookmarks
# please enter page number to stop on. enter 0 to download all pages.
# 2
# do you want to log in to ao3? (y/n)
# n
# downloading works
# finished downloading page 1. getting page 2
# too many requests to server. resuming in 5 minutes. paused at: 21:31:23
# resuming execution
# finished downloading page 2. getting page 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 ao3download.action()
#
# File ~/ao3downloader/ao3downloader/actions/ao3download.py:62, in action()
#      59 fileio.write_log(logfile, {'starting': link})
# ...
